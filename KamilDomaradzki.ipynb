# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/MachineLearnin2019_projects/blob/master/KamilDomaradzki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.callbacks import EarlyStopping

# %% [markdown]
# **Describe colums in dataset**
#
# *price* - price in US dollars (\$326--\$18,823) **(TARGET)**
#
# *carat* - weight of the diamond (0.2--5.01)
#
# *cut* - quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# *color* - diamond colour, from J (worst) to D (best)
#
# *clarity* -  a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# *x* - length in mm (0--10.74)
#
# *y* - width in mm (0--58.9)
#
# *z* - depth in mm (0--31.8)
#
# *depth* - total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# *table* - width of top of diamond relative to widest point (43--95)

# %%
diamond = pd.read_csv('https://raw.githubusercontent.com/K-Domar/MyRepo/main/diamonds.csv')
diamond = diamond.loc[:,~diamond.columns.str.match("Unnamed")]
diamond.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
#Describe csv file
diamond.describe()
# Out:
#               carat         depth  ...             y             z
# count  53940.000000  53940.000000  ...  53940.000000  53940.000000
# mean       0.797940     61.749405  ...      5.734526      3.538734
# std        0.474011      1.432621  ...      1.142135      0.705699
# min        0.200000     43.000000  ...      0.000000      0.000000
# 25%        0.400000     61.000000  ...      4.720000      2.910000
# 50%        0.700000     61.800000  ...      5.710000      3.530000
# 75%        1.040000     62.500000  ...      6.540000      4.040000
# max        5.010000     79.000000  ...     58.900000     31.800000
#
# [8 rows x 7 columns]

# %%
# check types of data in columns
diamond.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
# Looking for missing data

# Convert '0' to NaN
diamond[diamond==0] = np.nan

# Print the number of NaNs
print(diamond.isnull().sum())
# Out:
# carat       0
# cut         0
# color       0
# clarity     0
# depth       0
# table       0
# price       0
# x           8
# y           7
# z          20
# dtype: int64

# %%
# Drop the rows with missing values from diamond.csv
diamond = diamond.dropna()
diamond.shape
# Out:
# (53920, 10)

# %%
# Determine a problem type
diamond.price.hist(bins=30, alpha=0.8)
plt.show()

# %%
C_mat = diamond.corr()
fig = plt.figure(figsize = (5,5))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
plt.style.use('ggplot')
# EDA for categorical features 
names = ['color', 'cut', 'clarity']
fig = plt.figure(figsize=(20, 6))
for i in range(0,3):
  
  parameters = diamond.groupby(names[i], as_index=False)['price'].median()
  plt.subplot(1, 3, i+1)
  plt.bar(parameters[names[i]], parameters.price, width=0.5, alpha=0.8)
  plt.xlabel(names[i])
plt.subplot(1,3,1)
plt.ylabel('Median price')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# EDA for numerical features

name = ['carat', 'depth', 'table', 'x', 'y', 'z']
fig = plt.figure(figsize=(20, 12))
for i in range(0,6):
  num_parameters = diamond.groupby(name[i], as_index=False)['price'].mean()
  plt.subplot(2, 3, i+1)
  plt.scatter(x=num_parameters[name[i]], y=num_parameters['price'], alpha=0.5)
  plt.xlabel(name[i])
  plt.ylabel('Mean price')
  if i > 3:
    plt.xlim(0, 10)
plt.show()

# %%
#Feature Engineering

#One_Hot encoding

ohe_cut = pd.get_dummies(diamond['cut'], prefix='cut')
ohe_color = pd.get_dummies(diamond['color'], prefix='color')
ohe_clarity = pd.get_dummies(diamond['clarity'], prefix='clarity')

diamond = pd.concat([diamond, ohe_cut], axis=1)
diamond = pd.concat([diamond, ohe_color], axis=1)
diamond = pd.concat([diamond, ohe_clarity], axis=1)

#drop colums with type 'object'
diamond = diamond.select_dtypes(exclude=['object'])
diamond.shape
# Out:
# (53920, 27)

# %%
#Training data
X = diamond.drop('price', axis=1)
y = diamond['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# SIMPLE REGRESSION MODEL

# %%
#Random Forest
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
y_predicted = rf.predict(X_test)
rmse_rf = np.sqrt(MSE(y_test, y_predicted))
print("Root Mean Squared Error: {}".format(rmse_rf))
rf_score_train = rf.score(X_train, y_train)*100
rf_score_test = rf.score(X_test, y_test)*100
print("Score train = {0:.2f} %".format(rf_score_train))
print("Score test = {0:.2f} %".format(rf_score_test))
# Out:
# Root Mean Squared Error: 534.1013416128236
# Score train = 99.73 %
# Score test = 98.26 %

# %%
# Linear Regression

lr = LinearRegression(normalize=True)

lr.fit(X_train, y_train)
y_predicted = lr.predict(X_test)
rmse_lr = np.sqrt(MSE(y_test, y_predicted))
print("Root Mean Squared Error: {}".format(rmse_lr))
lr_score_train = lr.score(X_train, y_train)*100
lr_score_test = lr.score(X_test, y_test)*100
print("Score train = {0:.2f} %".format(lr_score_train))
print("Score test = {0:.2f} %".format(lr_score_test))
# Out:
# Root Mean Squared Error: 1115.8473902680207
# Score train = 91.91 %
# Score test = 92.39 %

# %%
#Lasso

lasso = Lasso(normalize=True)

lasso.fit(X_train, y_train)
y_predicted = lasso.predict(X_test)
rmse_lasso = np.sqrt(MSE(y_test, y_predicted))
print("Root Mean Squared Error: {}".format(rmse_lasso))
lasso_score_train = lasso.score(X_train, y_train)*100
lasso_score_test = lasso.score(X_test, y_test)*100
print("Score train = {0:.2f} %".format(lasso_score_train))
print("Score test = {0:.2f} %".format(lasso_score_test))
# Out:
# Root Mean Squared Error: 1421.466105481536
# Score train = 87.46 %
# Score test = 87.66 %

# %% [markdown]
# A NEURAL NETWORK

# %%
# Building a model

model = Sequential()
model.add(Dense(52, activation='relu', input_shape=(26,)))
model.add(Dense(52, activation='relu'))
model.add(Dense(52, activation='relu'))
model.add(Dense(52, activation='relu'))
model.add(Dense(1))

# creat a metrics 
from keras import backend as K

def coeff_determination(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

model.compile(optimizer='adam', loss='mean_squared_error', metrics=[coeff_determination])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 52)                1404
# _________________________________________________________________
# dense_16 (Dense)             (None, 52)                2756
# _________________________________________________________________
# dense_17 (Dense)             (None, 52)                2756
# _________________________________________________________________
# dense_18 (Dense)             (None, 52)                2756
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 53
# =================================================================
# Total params: 9,725
# Trainable params: 9,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Trainig model and scale values
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

early_stopping = EarlyStopping(monitor='val_loss', patience=6)

model_fit = model.fit(X_train, y_train,
          batch_size=100,
          epochs=100,
          verbose=1,
          validation_data=(X_test, y_test),
          callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 432/432 [==============================] - 1s 2ms/step - loss: 17552029.9284 - coeff_determination: -0.1753 - val_loss: 706770.8750 - val_coeff_determination: 0.9564
# Epoch 2/100
# 432/432 [==============================] - 1s 2ms/step - loss: 765797.9163 - coeff_determination: 0.9513 - val_loss: 544801.1875 - val_coeff_determination: 0.9663
# Epoch 3/100
# 432/432 [==============================] - 1s 2ms/step - loss: 718088.8815 - coeff_determination: 0.9557 - val_loss: 497233.3750 - val_coeff_determination: 0.9692
# Epoch 4/100
# 432/432 [==============================] - 1s 2ms/step - loss: 906158.1526 - coeff_determination: 0.9171 - val_loss: 473338.6250 - val_coeff_determination: 0.9707
# Epoch 5/100
# 432/432 [==============================] - 1s 2ms/step - loss: 495535.3176 - coeff_determination: 0.9672 - val_loss: 454545.0312 - val_coeff_determination: 0.9720
# Epoch 6/100
# 432/432 [==============================] - 1s 2ms/step - loss: 484992.6217 - coeff_determination: 0.9695 - val_loss: 449883.9062 - val_coeff_determination: 0.9724
# Epoch 7/100
# 432/432 [==============================] - 1s 2ms/step - loss: 468493.6736 - coeff_determination: 0.9697 - val_loss: 582486.8750 - val_coeff_determination: 0.9645
# Epoch 8/100
# 432/432 [==============================] - 1s 2ms/step - loss: 466319.9583 - coeff_determination: 0.9703 - val_loss: 427136.3438 - val_coeff_determination: 0.9737
# Epoch 9/100
# 432/432 [==============================] - 1s 2ms/step - loss: 452162.0259 - coeff_determination: 0.9700 - val_loss: 420610.9375 - val_coeff_determination: 0.9741
# Epoch 10/100
# 432/432 [==============================] - 1s 2ms/step - loss: 433358.7904 - coeff_determination: 0.9720 - val_loss: 516979.0000 - val_coeff_determination: 0.9684
# Epoch 11/100
# 432/432 [==============================] - 1s 2ms/step - loss: 423119.5463 - coeff_determination: 0.9728 - val_loss: 413574.8438 - val_coeff_determination: 0.9745
# Epoch 12/100
# 432/432 [==============================] - 1s 2ms/step - loss: 418883.9518 - coeff_determination: 0.9731 - val_loss: 415214.2500 - val_coeff_determination: 0.9745
# Epoch 13/100
# 432/432 [==============================] - 1s 2ms/step - loss: 397703.4781 - coeff_determination: 0.9745 - val_loss: 417900.6875 - val_coeff_determination: 0.9742
# Epoch 14/100
# 432/432 [==============================] - 1s 2ms/step - loss: 403760.3663 - coeff_determination: 0.9743 - val_loss: 404028.8125 - val_coeff_determination: 0.9751
# Epoch 15/100
# 432/432 [==============================] - 1s 2ms/step - loss: 401558.9945 - coeff_determination: 0.9742 - val_loss: 409188.9375 - val_coeff_determination: 0.9747
# Epoch 16/100
# 432/432 [==============================] - 1s 2ms/step - loss: 384215.7889 - coeff_determination: 0.9752 - val_loss: 401029.1250 - val_coeff_determination: 0.9753
# Epoch 17/100
# 432/432 [==============================] - 1s 2ms/step - loss: 388332.3708 - coeff_determination: 0.9743 - val_loss: 410320.0000 - val_coeff_determination: 0.9749
# Epoch 18/100
# 432/432 [==============================] - 1s 2ms/step - loss: 392999.8444 - coeff_determination: 0.9749 - val_loss: 406510.1562 - val_coeff_determination: 0.9751
# Epoch 19/100
# 432/432 [==============================] - 1s 2ms/step - loss: 382230.4574 - coeff_determination: 0.9755 - val_loss: 399531.3125 - val_coeff_determination: 0.9755
# Epoch 20/100
# 432/432 [==============================] - 1s 2ms/step - loss: 379929.5359 - coeff_determination: 0.9754 - val_loss: 406891.1562 - val_coeff_determination: 0.9749
# Epoch 21/100
# 432/432 [==============================] - 1s 2ms/step - loss: 381218.5126 - coeff_determination: 0.9755 - val_loss: 394424.1562 - val_coeff_determination: 0.9757
# Epoch 22/100
# 432/432 [==============================] - 1s 2ms/step - loss: 365492.3021 - coeff_determination: 0.9763 - val_loss: 386647.9375 - val_coeff_determination: 0.9762
# Epoch 23/100
# 432/432 [==============================] - 1s 2ms/step - loss: 379457.4592 - coeff_determination: 0.9758 - val_loss: 389941.3750 - val_coeff_determination: 0.9760
# Epoch 24/100
# 432/432 [==============================] - 1s 2ms/step - loss: 379584.1711 - coeff_determination: 0.9763 - val_loss: 400965.6875 - val_coeff_determination: 0.9752
# Epoch 25/100
# 432/432 [==============================] - 1s 2ms/step - loss: 374223.1925 - coeff_determination: 0.9761 - val_loss: 385808.7500 - val_coeff_determination: 0.9763
# Epoch 26/100
# 432/432 [==============================] - 1s 2ms/step - loss: 360049.2387 - coeff_determination: 0.9763 - val_loss: 387328.3125 - val_coeff_determination: 0.9761
# Epoch 27/100
# 432/432 [==============================] - 1s 2ms/step - loss: 358394.8030 - coeff_determination: 0.9769 - val_loss: 381630.3125 - val_coeff_determination: 0.9765
# Epoch 28/100
# 432/432 [==============================] - 1s 2ms/step - loss: 358242.4196 - coeff_determination: 0.9767 - val_loss: 386365.8750 - val_coeff_determination: 0.9763
# Epoch 29/100
# 432/432 [==============================] - 1s 2ms/step - loss: 377655.8579 - coeff_determination: 0.9753 - val_loss: 375332.7812 - val_coeff_determination: 0.9769
# Epoch 30/100
# 432/432 [==============================] - 1s 2ms/step - loss: 357188.1513 - coeff_determination: 0.9771 - val_loss: 386127.2188 - val_coeff_determination: 0.9763
# Epoch 31/100
# 432/432 [==============================] - 1s 2ms/step - loss: 372645.1243 - coeff_determination: 0.9765 - val_loss: 378504.7500 - val_coeff_determination: 0.9767
# Epoch 32/100
# 432/432 [==============================] - 1s 2ms/step - loss: 346829.8972 - coeff_determination: 0.9779 - val_loss: 393437.8750 - val_coeff_determination: 0.9759
# Epoch 33/100
# 432/432 [==============================] - 1s 2ms/step - loss: 357116.6815 - coeff_determination: 0.9768 - val_loss: 377091.9375 - val_coeff_determination: 0.9768
# Epoch 34/100
# 432/432 [==============================] - 1s 2ms/step - loss: 343624.3138 - coeff_determination: 0.9778 - val_loss: 369977.6250 - val_coeff_determination: 0.9773
# Epoch 35/100
# 432/432 [==============================] - 1s 2ms/step - loss: 355592.7557 - coeff_determination: 0.9770 - val_loss: 369045.2500 - val_coeff_determination: 0.9773
# Epoch 36/100
# 432/432 [==============================] - 1s 2ms/step - loss: 350361.2843 - coeff_determination: 0.9773 - val_loss: 369835.5312 - val_coeff_determination: 0.9772
# Epoch 37/100
# 432/432 [==============================] - 1s 2ms/step - loss: 368748.4912 - coeff_determination: 0.9767 - val_loss: 364345.8125 - val_coeff_determination: 0.9776
# Epoch 38/100
# 432/432 [==============================] - 1s 2ms/step - loss: 351610.7136 - coeff_determination: 0.9774 - val_loss: 363996.7812 - val_coeff_determination: 0.9776
# Epoch 39/100
# 432/432 [==============================] - 1s 2ms/step - loss: 340517.2843 - coeff_determination: 0.9778 - val_loss: 364841.3438 - val_coeff_determination: 0.9776
# Epoch 40/100
# 432/432 [==============================] - 1s 2ms/step - loss: 353311.6858 - coeff_determination: 0.9775 - val_loss: 365874.6250 - val_coeff_determination: 0.9774
# Epoch 41/100
# 432/432 [==============================] - 1s 2ms/step - loss: 347932.5103 - coeff_determination: 0.9778 - val_loss: 373706.4688 - val_coeff_determination: 0.9770
# Epoch 42/100
# 432/432 [==============================] - 1s 2ms/step - loss: 351404.3562 - coeff_determination: 0.9775 - val_loss: 359138.9375 - val_coeff_determination: 0.9778
# Epoch 43/100
# 432/432 [==============================] - 1s 2ms/step - loss: 345468.3047 - coeff_determination: 0.9781 - val_loss: 354982.9375 - val_coeff_determination: 0.9782
# Epoch 44/100
# 432/432 [==============================] - 1s 2ms/step - loss: 354222.3676 - coeff_determination: 0.9774 - val_loss: 375776.0000 - val_coeff_determination: 0.9768
# Epoch 45/100
# 432/432 [==============================] - 1s 2ms/step - loss: 340683.9768 - coeff_determination: 0.9777 - val_loss: 352727.7188 - val_coeff_determination: 0.9783
# Epoch 46/100
# 432/432 [==============================] - 1s 2ms/step - loss: 347097.7394 - coeff_determination: 0.9777 - val_loss: 357571.3438 - val_coeff_determination: 0.9779
# Epoch 47/100
# 432/432 [==============================] - 1s 2ms/step - loss: 329925.1044 - coeff_determination: 0.9784 - val_loss: 383153.6250 - val_coeff_determination: 0.9763
# Epoch 48/100
# 432/432 [==============================] - 1s 2ms/step - loss: 339880.5867 - coeff_determination: 0.9782 - val_loss: 365620.0625 - val_coeff_determination: 0.9776
# Epoch 49/100
# 432/432 [==============================] - 1s 2ms/step - loss: 348988.4410 - coeff_determination: 0.9773 - val_loss: 352531.8750 - val_coeff_determination: 0.9783
# Epoch 50/100
# 432/432 [==============================] - 1s 2ms/step - loss: 333730.1100 - coeff_determination: 0.9780 - val_loss: 355884.5625 - val_coeff_determination: 0.9781
# Epoch 51/100
# 432/432 [==============================] - 1s 2ms/step - loss: 341613.4377 - coeff_determination: 0.9780 - val_loss: 354736.0625 - val_coeff_determination: 0.9782
# Epoch 52/100
# 432/432 [==============================] - 1s 2ms/step - loss: 334886.3813 - coeff_determination: 0.9785 - val_loss: 356266.6250 - val_coeff_determination: 0.9781
# Epoch 53/100
# 432/432 [==============================] - 1s 2ms/step - loss: 343317.3354 - coeff_determination: 0.9779 - val_loss: 350660.0625 - val_coeff_determination: 0.9785
# Epoch 54/100
# 432/432 [==============================] - 1s 2ms/step - loss: 339126.6695 - coeff_determination: 0.9783 - val_loss: 368012.7500 - val_coeff_determination: 0.9773
# Epoch 55/100
# 432/432 [==============================] - 1s 2ms/step - loss: 328456.9446 - coeff_determination: 0.9790 - val_loss: 347940.6875 - val_coeff_determination: 0.9786
# Epoch 56/100
# 432/432 [==============================] - 1s 2ms/step - loss: 332970.0603 - coeff_determination: 0.9786 - val_loss: 347788.0625 - val_coeff_determination: 0.9786
# Epoch 57/100
# 432/432 [==============================] - 1s 2ms/step - loss: 339646.4124 - coeff_determination: 0.9788 - val_loss: 347687.7500 - val_coeff_determination: 0.9786
# Epoch 58/100
# 432/432 [==============================] - 1s 2ms/step - loss: 329158.5757 - coeff_determination: 0.9789 - val_loss: 347184.0625 - val_coeff_determination: 0.9786
# Epoch 59/100
# 432/432 [==============================] - 1s 2ms/step - loss: 331449.6730 - coeff_determination: 0.9789 - val_loss: 347657.8750 - val_coeff_determination: 0.9786
# Epoch 60/100
# 432/432 [==============================] - 1s 2ms/step - loss: 323269.2565 - coeff_determination: 0.9791 - val_loss: 351238.8750 - val_coeff_determination: 0.9783
# Epoch 61/100
# 432/432 [==============================] - 1s 2ms/step - loss: 321318.6926 - coeff_determination: 0.9792 - val_loss: 347702.8438 - val_coeff_determination: 0.9786
# Epoch 62/100
# 432/432 [==============================] - 1s 2ms/step - loss: 320997.5560 - coeff_determination: 0.9793 - val_loss: 344599.2500 - val_coeff_determination: 0.9788
# Epoch 63/100
# 432/432 [==============================] - 1s 2ms/step - loss: 326744.8204 - coeff_determination: 0.9791 - val_loss: 350969.3750 - val_coeff_determination: 0.9783
# Epoch 64/100
# 432/432 [==============================] - 1s 2ms/step - loss: 327938.5065 - coeff_determination: 0.9792 - val_loss: 346092.9375 - val_coeff_determination: 0.9787
# Epoch 65/100
# 432/432 [==============================] - 1s 2ms/step - loss: 333542.2857 - coeff_determination: 0.9782 - val_loss: 349540.7812 - val_coeff_determination: 0.9784
# Epoch 66/100
# 432/432 [==============================] - 1s 2ms/step - loss: 320339.2216 - coeff_determination: 0.9795 - val_loss: 342840.2500 - val_coeff_determination: 0.9789
# Epoch 67/100
# 432/432 [==============================] - 1s 2ms/step - loss: 335578.0590 - coeff_determination: 0.9781 - val_loss: 340468.8750 - val_coeff_determination: 0.9791
# Epoch 68/100
# 432/432 [==============================] - 1s 2ms/step - loss: 329615.6290 - coeff_determination: 0.9790 - val_loss: 346272.7500 - val_coeff_determination: 0.9786
# Epoch 69/100
# 432/432 [==============================] - 1s 2ms/step - loss: 327013.5202 - coeff_determination: 0.9791 - val_loss: 345914.6562 - val_coeff_determination: 0.9787
# Epoch 70/100
# 432/432 [==============================] - 1s 2ms/step - loss: 327478.6934 - coeff_determination: 0.9784 - val_loss: 343379.4062 - val_coeff_determination: 0.9789
# Epoch 71/100
# 432/432 [==============================] - 1s 2ms/step - loss: 326528.6520 - coeff_determination: 0.9791 - val_loss: 346162.7188 - val_coeff_determination: 0.9787
# Epoch 72/100
# 432/432 [==============================] - 1s 2ms/step - loss: 331810.6679 - coeff_determination: 0.9788 - val_loss: 335747.1250 - val_coeff_determination: 0.9794
# Epoch 73/100
# 432/432 [==============================] - 1s 2ms/step - loss: 302345.5406 - coeff_determination: 0.9799 - val_loss: 351174.3438 - val_coeff_determination: 0.9783
# Epoch 74/100
# 432/432 [==============================] - 1s 2ms/step - loss: 325615.3422 - coeff_determination: 0.9790 - val_loss: 347899.5938 - val_coeff_determination: 0.9786
# Epoch 75/100
# 432/432 [==============================] - 1s 2ms/step - loss: 325063.4731 - coeff_determination: 0.9788 - val_loss: 340655.1562 - val_coeff_determination: 0.9790
# Epoch 76/100
# 432/432 [==============================] - 1s 2ms/step - loss: 326305.5579 - coeff_determination: 0.9787 - val_loss: 338613.5312 - val_coeff_determination: 0.9792
# Epoch 77/100
# 432/432 [==============================] - 1s 2ms/step - loss: 330102.1119 - coeff_determination: 0.9790 - val_loss: 337291.8438 - val_coeff_determination: 0.9792
# Epoch 78/100
# 432/432 [==============================] - 1s 2ms/step - loss: 313987.9821 - coeff_determination: 0.9796 - val_loss: 344345.0938 - val_coeff_determination: 0.9787

# %%
# evaluate loaded model
scores_train = model.evaluate(X_train, y_train, verbose=0)
scores_test  = model.evaluate(X_test,  y_test,  verbose=0)

y_model = model.predict(X_test)
rmse = np.sqrt(MSE(y_test, y_model))
print("Root Mean Squared Error: {}".format(rmse))

print("Accuracy Train: %.2f%% , Test: %.2f%% " % (scores_train[1]*100, scores_test[1]*100 ))
# Out:
# Root Mean Squared Error: 586.8092632616936
# Accuracy Train: 97.87% , Test: 97.76%

# %%
n_epochs = len(model_fit.history['loss'])

plt.figure(1)
plt.plot(model_fit.history['loss'],'r')
plt.plot(model_fit.history['val_loss'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.ylim(300000,1000000) 
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %%
#Summary

labels = ['Random Forest Regressor', 'Linear Regression', 'Lasso', 'Neural Network']
accuracy_train = [rf_score_train, lr_score_train, lasso_score_train, scores_train[1]*100]
accuracy_test = [rf_score_test, lr_score_test, lasso_score_test, scores_test[1]*100]
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, accuracy_train, width, label='Train')
rects2 = ax.bar(x + width/2, accuracy_test, width, label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy [%]')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()
